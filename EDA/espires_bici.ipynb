# %%
import pandas as pd

# %%
espires = pd.read_csv('../data/espires_bici.csv')
espires.head()
# Out:
# /var/folders/vs/5hqqq9px6_z7w4dnv2j4238m0000gn/T/ipykernel_17264/1832672302.py:1: DtypeWarning: Columns (0,1,3,9,10,11,12,13,14,16,18,19,20,21,23,24,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   espires = pd.read_csv('data/espires_bici.csv')
#                      Geo Point  \
# 0   39.4534281344,-0.371417928
# 1  39.4701858226,-0.3434149115
# 2  39.4823568143,-0.3910134347
# 3  39.4795695506,-0.3610574679
# 4  39.4617384023,-0.3591412053
#
#                                            Geo Shape  angulo  \
# 0  {"coordinates": [-0.371417928, 39.4534281344],...    30.0
# 1  {"coordinates": [-0.3434149115, 39.4701858226]...   251.0
# 2  {"coordinates": [-0.3910134347, 39.4823568143]...   184.0
# 3  {"coordinates": [-0.3610574679, 39.4795695506]...    70.0
# 4  {"coordinates": [-0.3591412053, 39.4617384023]...   166.0
#
#   fecha_actualizacion  hora_actualizacion    idpm   ih             datetime  \
# ...

# %%
espires.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10059654 entries, 0 to 10059653
# Data columns (total 27 columns):
#  #   Column                                    Dtype
# ---  ------                                    -----
#  0   Geo Point                                 object
#  1   Geo Shape                                 object
#  2   angulo                                    float64
#  3   fecha_actualizacion                       object
#  4   hora_actualizacion                        float64
#  5   idpm                                      float64
#  6   ih                                        float64
#  7   datetime                                  object
#  8   Àngul / Ángulo                            float64
#  9   Data Actualització / Fecha Actualización  object
#  10  Hora Actualització / Hora Actualización   object
#  11  fiwareid                                  object
#  12  geo_shape                                 object
# ...

# %%
espires.describe()
# Out:
#              angulo  hora_actualizacion          idpm            ih  \
# count  3.319200e+06        7.468200e+05  9.786154e+06  4.408615e+06
# mean   1.610667e+02        2.022101e+13  1.855971e+03  4.997494e+01
# std    6.815531e+01        2.343752e-02  1.197105e+03  1.114869e+02
# min    3.000000e+01        2.022101e+13  0.000000e+00 -1.000000e+00
# 25%    1.177500e+02        2.022101e+13  1.043000e+03  0.000000e+00
# 50%    1.610000e+02        2.022101e+13  1.544000e+03  0.000000e+00
# 75%    2.100000e+02        2.022101e+13  2.628000e+03  6.000000e+01
# max    3.260000e+02        2.022101e+13  5.006000e+03  9.628000e+03
#
#        Àngul / Ángulo      OBJECTID  hora_actua         gid
# count    3.730320e+06  15930.000000         0.0  135.000000
# mean     1.659481e+02    203.000000         NaN  203.000000
# std      6.661658e+01     38.971297         NaN   39.115214
# min      3.000000e+01    136.000000         NaN  136.000000
# ...

# %%
espires.count()
# Out:
# Geo Point                                    3319200
# Geo Shape                                    3319200
# angulo                                       3319200
# fecha_actualizacion                           750357
# hora_actualizacion                            746820
# idpm                                         9786154
# ih                                           4408615
# datetime                                    10059654
# Àngul / Ángulo                               3730320
# Data Actualització / Fecha Actualización     1082692
# Hora Actualització / Hora Actualización       719280
# fiwareid                                      284566
# geo_shape                                    6466954
# geo_point_2d                                 6466954
# globalid                                       33615
# OBJECTID                                       15930
# fecha_actu                                      3186
# hora_actua                                         0
# ...

# %%
e = pd.read_csv('espires_bici01-01-2023_00-00-02.csv', sep=';')
e.head()
# Out:
#                      Geo Point  \
# 0  39.4761065759,-0.3930172919
# 1  39.4830214772,-0.3795902989
# 2  39.4875811893,-0.3883149929
# 3  39.4772727258,-0.3679871844
# 4  39.4929344573,-0.3832858719
#
#                                            Geo Shape  angulo  \
# 0  {"coordinates": [-0.3930172919, 39.4761065759]...     120
# 1  {"coordinates": [-0.3795902989, 39.4830214772]...     177
# 2  {"coordinates": [-0.3883149929, 39.4875811893]...     131
# 3  {"coordinates": [-0.3679871844, 39.4772727258]...     184
# 4  {"coordinates": [-0.3832858719, 39.4929344573]...     288
#
#    fecha_actualizacion  hora_actualizacion  idpm  ih
# 0                  NaN                 NaN   835   0
# 1                  NaN                 NaN  1165   0
# 2                  NaN                 NaN  1045   0
# 3                  NaN                 NaN  1441   0
# 4                  NaN                 NaN  4025   0
